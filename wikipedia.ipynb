# %%
from requests import get 
from lxml import html
a = get("https://en.wikipedia.org/wiki/Linus_Torvalds")
if a.status_code==200:
    #with open("/home/aytac/Desktop/wiki/te.html","w") as f:
        #f.write(a.text)
    gelen=html.fromstring(a.text) 
    #gelen.xpath("/html/body/p/text()")
    tek=gelen.xpath("//a")  #axtaris ucun      
    for i in tek:
        href=i.attrib.get('href')                                        #if
        if href is not None and not str(href).startswith("#"):           #if heqiqi link qaytarsin defe
            href="https://en.wikipedia.org"+str(i.attrib.get('href'))    #if
            print(href)                                                  #if
            #sorgu=get(href)                                                                #hemin linklere sorgu  
            #if sorgu.status_code==200:                                                     # sehife dogrudusa
                #with open("/home/aytac/Desktop/wiki/"+ str(hash(href))+".html","w") as f:           #hash xususu 
                    #f.write(sorgu.text)                                                             #yazir
            
        
        
        #print(i.attrib)     #(i.attrib['href']) ai-nin icindeki link goturmek istiyende attrip-dictinary
        
        #print(i.attrib.get('href'))  #getnen yazanda olsa qaytaracaq olmasa none qaytaracaq linkin adinin verir(a-nin link)
        #print("https://en.wikipedia.org"+str(i.attrib.get('href'))) #link qaytarir linkin ozunu
        #print(i)
# Out:
# https://en.wikipedia.org/wiki/File:LinuxCon_Europe_Linus_Torvalds_03_(cropped).jpg
# https://en.wikipedia.org/wiki/Helsinki
# https://en.wikipedia.org/wiki/Dunthorpe,_Oregon
# https://en.wikipedia.org/wiki/University_of_Helsinki
# https://en.wikipedia.org/wiki/Software_engineer
# https://en.wikipedia.org/wiki/Linux_Foundation
# https://en.wikipedia.org/wiki/Linux
# https://en.wikipedia.org/wiki/Git_(software)
# https://en.wikipedia.org/wiki/Subsurface_(software)
# https://en.wikipedia.org/wiki/Nils_Torvalds
# https://en.wikipedia.org/wiki/Leo_T%C3%B6rnqvist
# https://en.wikipedia.org/wiki/Ole_Torvalds
# https://en.wikipedia.org/wiki/Help:IPA/English
# https://en.wikipedia.org/wiki/Help:IPA/Swedish
# https://en.wikipedia.org/wiki/File:Sv-Linus_Torvalds2.ogg
# https://en.wikipedia.org//upload.wikimedia.org/wikipedia/commons/3/3c/Sv-Linus_Torvalds2.ogg
# https://en.wikipedia.org/wiki/Finland
# https://en.wikipedia.org/wiki/Software_engineering
# ...
